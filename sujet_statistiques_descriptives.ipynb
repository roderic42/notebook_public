# %% [markdown]
# # Données disponibles et indications générales
#
# Le fichier à traiter contient les données météo (température \[°C\], humidité relative \[%\], vent moyen \[noeuds\], vent en rafales \[noeuds\]) de plusieurs sites dans le monde entre 2017 et 2021. Toutes ces données sont extraites du site [https://mesonet.agron.iastate.edu/request/download.phtml](https://mesonet.agron.iastate.edu/request/download.phtml)
#
# ## Description des données
#
# Le fichier de données est composé de 14 colonnes et d'approximativement 400000 lignes. Les colonnes sont les suivantes :
# 1. Numéro du site
# 2. Longitude du site (positive vers l'est)
# 3. Latitude du site (positive vers le nord)
# 4. Altitude du site
# 5. Température en °C
# 6. Humidité relative en %
# 7. Vitesse du vent en noeuds
# 8. Vitesse des rafales en noeuds
# 9. Année
# 10. Mois
# 11. Jour
# 12. Heure
# 13. Année décimale (utile pour certaines représentations)
#
# Les sites utilisés sont les suivants :
#
# | Numéro | Ville | Pays | Latitude \[°\] | Longitude \[°\] | Altitude \[m\] |
# | ------ | ----- | ---- | -------- | --------- | -------- |
# | 1 | Adrar | Algérie | 27.88 | -0.18 | 263 |
# | 2 | Brest | France | 48.44 | -4.41 | 103 |
# | 3 | Juan Mendoza | Bolivie | -17.96 | -67.08 | 3702 |
# | 4 | Khabarovsk | Russie | 48.52 | 135.17 | 72 |
# | 5 | Kuching | Malaisie | 1.48 | 110.33 | 27 |
# | 6 | Telfer | Australie| -21.72 | 122.23 | 296 |
# | 7 | Alert | Canada | 82.52 | -62.28 | 31 |
# | 8 | Amundsen | Antarctique | -90.00 | 0.00 | 2830 |
#
# Les données sont disponibles sur moodle : [https://moodle.ensta-bretagne.fr/mod/resource/view.php?id=59088](https://moodle.ensta-bretagne.fr/mod/resource/view.php?id=59088)
#
# ## Indications générales sur le TD
#
# Ce TD utilise plusieurs fonctions de haut niveau de matplotlib : il est important de lire la documentation qui les concerne. Le plus souvent, un lien est mis vers la documentation depuis le sujet, mais il est possible que vous ayez besoin d'autres fonctions (par exemple, si la syntaxe de plot ne vous est pas familière, ou la façon de définir des couleurs, etc.).
#
# Ce TD affiche quantité de courbes, histogrammes, ou autres objets graphiques. Par défaut, pycharm les ouvre dans un onglet spécifique, mais il peut être préférable de les ouvrir dans une fenêtre autonome. Pour cela, il faut désactiver l'option idoine dans File | Settings | Tools | Python Scientific | Show plots in tool window.
#
# Une option qui peut être intéressante dans Pycharm est d'activer la console Python et l'explorateur de variables, il faut aller dans Run | Edit configurations et sélectionner Run with Python console. Il se peut que l'option ne soit pas présente, dans ce cas il faut exécuter au moins une fois votre programme et elle apparaîtra.
#
# Le sujet est probablement trop long. Les questions les plus importantes ont été placées en début de sujet.
#
# ## Forme du TD : notebook jupyter
#
# Le sujet du TD est présenté sous forme de notebook jupyter [https://jupyter.org/](https://jupyter.org/). Cette forme permet de présenter dans un même document du texte, du code Python et des résultats d'exécution de programmes. N'hésitez pas à copier-coller le code fourni.
#
# **Remarque** : toutes les fonctions dont le nom commence par "q" suivi d'un numéro sont à écrire.
#
# Vous pourrez répondre au TD dans un notebook (si vous avez installé l'environnement nécessaire) ou dans un programme Python classique. Dans ce dernier cas, partez du squelette de programme fourni sur moodle : [https://moodle.ensta-bretagne.fr/mod/resource/view.php?id=59087](https://moodle.ensta-bretagne.fr/mod/resource/view.php?id=59087).

# %% [markdown]
# ## Statistiques générales
#
# Chargez les données comme indiqué dans le code ci-dessous. Un dictionnaire permettant la correspondance numéro de site / nom de ville a été défini. Vous pourrez l'utiliser ou pas selon votre préférence.
#
# Une fois le fichier chargé, calculez pour les 4 variables météo (température, humidité relative, vitesse du vent, vitesse en rafales) :
# 1. La moyenne
# 2. L'écart-type
# 3. La médiane
#
# **Remarques :**
# - certaines valeurs ne sont pas renseignées et valent NaN (Not A Number). Pour extraire les statistiques demandées, il faudra utiliser les fonctions de numpy préfixées par `nan`. Par exemple la moyenne se calculera par `nanmean` ; voir la documentation de numpy [https://numpy.org/doc/stable/reference/routines.statistics.html](https://numpy.org/doc/stable/reference/routines.statistics.html)
# - une bonne partique consiste à limiter le nombre de chiffres significatifs affichés. Avec les données fournies, un affichage avec 2 chiffres après la virgule est raisonnable.
# ```python
# # Exemple d'affichage de pi avec 3 chiffres après la virgule
# print('{:.3f}'.format(np.pi))
# ```

# %%
import numpy as np
from corrige_stats import *

# Correspondance numéros / noms
noms = {1: 'Adrar (Algérie)',
        2: 'Brest (France)',
        3: 'Juan Mendoza (Bolivie)',
        4: 'Khabarovsk (Russie)',
        5: 'Kuching (Malaisie)',
        6: 'Telfer (Australie)',
        7: 'Alert (Canada)',
        8: 'Amundsen (Antarctique)'}
# Noms des différentes colonnes
cols = ['station', 'Longitude', 'Latitude', 'Altitude', 'Température [°C]', 'Humidité relative [%]',
        'Vent [nd]', 'Rafales [nd]', 'Année', 'Mois', 'Jour', 'Heure', 'Decimal year']
# Chargement des données (dans cet exemple le fichier est rangé dans le répertoire data)
data = np.loadtxt('data/meteo.txt', skiprows=1)
# Vérification : afficher le nombre de lignes et de colonnes des données
print(data.shape)
q1_statistiques(data, cols)
# Out:
# (399631, 13)
# Température [°C] : moyenne 13.90, écart-type 18.05, médiane 17.00
# Humidité relative [%] : moyenne 68.03, écart-type 26.54, médiane 74.77
# Vent [nd] : moyenne 7.47, écart-type 5.31, médiane 6.00
# Rafales [nd] : moyenne 28.62, écart-type 6.47, médiane 28.00

# %% [markdown]
# ## Position des sites
#
# Pour information la position des différents sites est réprésentée sur la carte ci-après. Cette représentation utilise le module `folium` qui n'est utilisable que dans un *notebook*.

# %%
from folium import Map, Marker, TileLayer

# Carte dézoomée au maximum, centrée sur 10° sud
m = Map(zoom_start=0, location=(-10, 0))
# Fond de carte utilisé
TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = False,
        control = True
       ).add_to(m)
# Listes longitudes, latitudes et noms (une valeur par site)
lon = []
lat = []
villes = []
for i in noms.keys():
    # Récupération de la première ligne pour chaque site
    idx = np.argwhere(data[:, 0] == i)[0,0]
    lon.append(data[idx, 1])
    lat.append(data[idx, 2])
    villes.append(noms[i])
# Ajout d'un marqueur pour chaque site. Le nom de la ville apparaît lors d'un survol du marqueur
for i in range(len(villes)):
    Marker(location=(lat[i], lon[i]), title=villes[i], draggable=False).add_to(m)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Affichage de séries temporelles
#
# Extraire les données d'un site (par exemple Brest) et afficher les séries temporelles des 4 variables météo.
# La fonction `plt.subplots` permettra de représenter les 4 variables sur la même figure.
#
# On remarquera le grand nombre de valeur NaN dans les données de rafales.

# %%
import matplotlib.pyplot as plt

fig, axe  = plt.subplots(2, 2, sharex=True, sharey=False, figsize=(8, 6))
# Exemple d'utilisation du subplots :
# axe[0, 0].plot(t, x)
q2_serie_temporelle(data, axe, cols)
# Optionnel : ajout d'une grille
for ax in axe.flatten():
    ax.grid()

# %% [markdown]
# ## Histogrammes
#
# Utiliser la fonction [plt.hist](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html) pour tracer les histogrammes des 4 variables pour un site (Brest dans l'exemple).
# On utilisera une valeur de densité plutôt que d'effectifs pour déterminer la hauteur des barres de l'histogramme.
#
# **Remarques** :
# - Les histogrammes seront affichés avec 20 classes (bins). Il existe des heuristiques pour déterminer automatiquement ce nombre (voir cours de statistiques du semestre 2). La fonction [numpy.histogram_bin_edges](https://numpy.org/devdocs/reference/generated/numpy.histogram_bin_edges.html) permet de l'estimer selon plusieurs heuristiques classiques.
# - Pour visualiser clairement la frontière des différentes classes, il est possible d'utiliser le paramètre `edgecolor`

# %%
fig, axe  = plt.subplots(2, 2, sharex=False, sharey=False, figsize=(8, 6))
# Exemple d'utilisation du subplots :
# axe[0, 0].hist(t, x)
q3_hist(data, axe, cols)

# %% [markdown]
# ## Histogrammes cumulés
#
# Tracer la courbe cumulative des données météo d'un site (Brest dans l'exemple).

# %%
fig, axe  = plt.subplots(2, 2, sharex=False, sharey=False, figsize=(8, 6))
q4_hist_c(data, axe, cols)

# %% [markdown]
# ## Boîtes à moustaches
#
# Pour le site de brest, réaliser un affichage synthétique des valeurs de température de chaque mois sous forme de boîtes à moustaches.
# Pour cela, on utilisera la fonction [plt.boxplot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html)
#
# Indications :
# - Il faudra au préalable extraire les lignes pour lesquelles la température est définie
# - Il faudra ensuite créer une liste de `numpy.array` de températures pour chaque mois.
# - Lors de l'utilisation de `boxplot`, utiliser l'option permettant d'afficher la moyenne dans les boîtes à moustaches
#
# Remarques :
# - il est possible de désactiver les valeurs extrêmes (option `showfliers`)
# - il est possible de modifier la longueur des moustaches (option `whis`)

# %%
# Extraction des températures valides (utiliser `np.isfinite` ou `~np.isnan`)
data_tmpc_ok = data[np.isfinite(data[:, 4]), :]
q5_boxplot(data_tmpc_ok)
plt.gca().set_xlabel(cols[9])
plt.gca().set_ylabel(cols[4])
# Out:
# Text(0, 0.5, 'Température [°C]')

# %% [markdown]
# ## Comparaison boîtes à moustaches et diagrammes en violon par station
#
# Pour chaque site, afficher les données de température et d'humidité relative sous forme de  boîtes à moustache puis sous forme de diagrammes en violon.
# Le principe est similaire à celui de la question précédente. La fonction [plt.violinplot](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.violinplot.html) permet de tracer les diagrammes en violon. Selon les données, les boîtes à moustache ou les diagrammes en violon seront plus lisibles.
#
# La commande `plt.subplots` sera utilisée pour mettre les deux figures côte à côte.

# %%
# Noms des stations sous forme de liste
lst_noms = [noms[i] for i in noms.keys()]
# Données d'humidité relative sans les NaN
data_relh_ok = data[np.isfinite(data[:, 5])]
# Ne pas partager les abscisses : intervalles différents pour les températures et l'humidité relative.
fig, ax = plt.subplots(2, 2, sharex=False, sharey=True, figsize=(10, 8))
# Boîtes à moustache pour la température
q6_boxplot(data_tmpc_ok, ax[0, 0], 4, cols, noms)
# Boîtes à moustache pour l'humidité relative
q6_boxplot(data_relh_ok, ax[0, 1], 5, cols, noms)
# Diagramme en violon pour la température
q6_violinplot(data_tmpc_ok, ax[1, 0], 4, cols, noms)
# Diagramme en violon pour l'humidité relative
q6_violinplot(data_relh_ok, ax[1, 1], 5, cols, noms)

# Légende des ordonnées : noms des stations
_ = plt.yticks(list(noms.keys()), lst_noms)

# %% [markdown]
# ## Histogrammes 2D
#
# Matplotlib propose deux fonctions pour tracer des histogrammes 2D : une avec des mailles carrées ([plt.hist2d](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist2d.html)) et une avec des mailles hexagonales ([plt.hexbin](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hexbin.html)).
#
# Utiliser ces deux fonctions pour représenter l'humidité relative en fonction de la température pour le site de Brest.
# Il ne faudra grder que les données possédant une température ET une humidité relative valides (différentes de NaN).
#
# Pour la fonction `hist2d` il faudra régler le nombre de classes en passant un tuple au paramètre `bins`. Pour la fonction `hexbin`, le réglage se fera grâce au paramètre `gridsize`.

# %%
fig, axe  = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(12, 5))
q7_hist2_hex(data, axe, cols)

# %% [markdown]
# ## Découpage par tranches, lissage des données
#
# Pour chaque station, découper les données par année et par mois, et pour chaque tranche calculer la médiane des températures (il serait possible de calculer la moyenne, mais la médiane est un indicateur statistique plus robuste.)
#
# Tracer les courbes ainsi obtenues en fonction de la date.

# %%
q8_lissage(data_tmpc_ok, cols, noms)

# %% [markdown]
# ## Températures avec intervalles de confiance
#
# Reprenons le découpage précédent, mais uniquement pour le site de Brest. Pour chaque tranche, il faut extraire la moyenne et l'écart-type (attention aux valeurs NaN : utiliser les fonctions `numpy` préfixées par `nan`).
#
# Sous hypothèse d'une distribution Normale, le rayon de l'intervalle de confiance à 95% est de $1.96\sigma$ avec $\sigma$ l'écart-type.
#
# Pour chaque date, tracer l'intervalle de confiance à 95% des températures de Brest grâce à la commande [plt.errorbar](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.errorbar.html).

# %%
q9_inter(data, cols)

# %% [markdown]
# ## Cartes de chaleur
#
# En utilisant les fonctions fournies, afficher une carte de chaleur (*heatmap*) des températures  et de l'humidité relative pour chaque mois (abscisse) et pour chaque station (ordonnée).
#
# Le premier paramètre de la fonction `heatmap` sera une matrice *nombre de villes* * 12 dans laquelle chaque case contient la moyenne des valeurs pour la ville et le mois.
#
# **Remarque** :
# - Attention, pour le site Amundsen il n'y a aucune donnée d'humidité lors de certains mois. Dans ce cas, la valeur doit être NaN

# %%
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable


"""https://matplotlib.org/stable/gallery/images_contours_and_fields/image_annotated_heatmap.html
"""
def heatmap(data, row_labels, col_labels, ax=None,
            cbar_kw={}, cbarlabel="", **kwargs):
    """
    Create a heatmap from a numpy array and two lists of labels.

    Parameters
    ----------
    data
        A 2D numpy array of shape (M, N).
    row_labels
        A list or array of length M with the labels for the rows.
    col_labels
        A list or array of length N with the labels for the columns.
    ax
        A `matplotlib.axes.Axes` instance to which the heatmap is plotted.  If
        not provided, use current axes or create a new one.  Optional.
    cbar_kw
        A dictionary with arguments to `matplotlib.Figure.colorbar`.  Optional.
    cbarlabel
        The label for the colorbar.  Optional.
    **kwargs
        All other arguments are forwarded to `imshow`.
    """

    if not ax:
        ax = plt.gca()

    # Plot the heatmap
    im = ax.imshow(data, **kwargs)

    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    
    # Create colorbar
    cbar = plt.colorbar(im, cax=cax, **cbar_kw)
    cbar.ax.set_ylabel(cbarlabel, rotation=-90, va="bottom")

    # Show all ticks and label them with the respective list entries.
    ax.set_xticks(np.arange(data.shape[1]), labels=col_labels)
    ax.set_yticks(np.arange(data.shape[0]), labels=row_labels)

    # Let the horizontal axes labeling appear on top.
    # ax.tick_params(top=True, bottom=False, labeltop=True, labelbottom=False)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=-30, ha="right",
             rotation_mode="anchor")

    # Turn spines off and create white grid.
    ax.spines[:].set_visible(False)

    ax.set_xticks(np.arange(data.shape[1]+1)-.5, minor=True)
    ax.set_yticks(np.arange(data.shape[0]+1)-.5, minor=True)
    ax.grid(which="minor", color="w", linestyle='-', linewidth=3)
    ax.tick_params(which="minor", bottom=False, left=False)

    return im, cbar


def annotate_heatmap(im, data=None, valfmt="{x:.2f}",
                     textcolors=("black", "white"),
                     threshold=None, **textkw):
    """
    A function to annotate a heatmap.

    Parameters
    ----------
    im
        The AxesImage to be labeled.
    data
        Data used to annotate.  If None, the image's data is used.  Optional.
    valfmt
        The format of the annotations inside the heatmap.  This should either
        use the string format method, e.g. "$ {x:.2f}", or be a
        `matplotlib.ticker.Formatter`.  Optional.
    textcolors
        A pair of colors.  The first is used for values below a threshold,
        the second for those above.  Optional.
    threshold
        Value in data units according to which the colors from textcolors are
        applied.  If None (the default) uses the middle of the colormap as
        separation.  Optional.
    **kwargs
        All other arguments are forwarded to each call to `text` used to create
        the text labels.
    """

    if not isinstance(data, (list, np.ndarray)):
        data = im.get_array()

    # Normalize the threshold to the images color range.
    if threshold is not None:
        threshold = im.norm(threshold)
    else:
        threshold = im.norm(data.max())/2.

    # Set default alignment to center, but allow it to be
    # overwritten by textkw.
    kw = dict(horizontalalignment="center",
              verticalalignment="center")
    kw.update(textkw)

    # Get the formatter in case a string is supplied
    if isinstance(valfmt, str):
        valfmt = matplotlib.ticker.StrMethodFormatter(valfmt)

    # Loop over the data and create a `Text` for each "pixel".
    # Change the text's color depending on the data.
    texts = []
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            kw.update(color=textcolors[int(im.norm(np.array(data[i, j])) > threshold)])
            if np.ma.is_masked(data[i, j]):
                valstr = '-'
            else:
                valstr = valfmt(data[i, j], None)
            text = im.axes.text(j, i, valstr, **kw)
            texts.append(text)

    return texts

# %%
# Matrice site/mois
matrix_tmpc = q10_matrice(data, 4, noms)
matrix_relh = q10_matrice(data, 5, noms)

fig, ax  = plt.subplots(2, 1, sharex=False, sharey=False, figsize=(8, 12))

# Transformation du dictionnaire en liste
villes = [noms[k] for k in noms.keys()]
# Utilisation de la fonction heatmap
im1, cbar1 = heatmap(matrix_tmpc, villes, np.arange(1, 13), ax[0], cmap='coolwarm', vmin=-35, vmax=35)
# Ajout des annotations
text1 = annotate_heatmap(im1, valfmt="{x:.1f}", textcolors=('k', 'k'))
ax[0].set_xlabel('Mois')
ax[0].set_title('Température [°C]')
im2, cbar2 = heatmap(matrix_relh, villes, np.arange(1, 13), ax[1], cmap='Blues')
text2 = annotate_heatmap(im2, valfmt="{x:.1f}")
ax[1].set_xlabel('Mois')
ax[1].set_title('Humidité relative [%]')

# plt.tight_layout()
# Out:
# Text(0.5, 1.0, 'Humidité relative [%]')
